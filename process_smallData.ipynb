# %% [markdown]
# Import thư viện

# %%
import pandas as pd
import ast

# Đọc file behaviors.tsv (user, lịch sử đọc, tin được hiển thị)
behaviors = pd.read_csv(r'MINDsmall_dev\behaviors.tsv', sep='\t', header=None,
                        names=['impression_id', 'user_id', 'time', 'history', 'impressions'])

# Đọc file news.tsv (tin tức, thể loại, entity liên quan)
news = pd.read_csv(r'MINDsmall_dev\news.tsv', sep='\t', header=None,
                   names=['news_id', 'category', 'subcategory', 'title', 'abstract', 'url', 'entities', 'abstract_entities'])

print("✅ behaviors:", behaviors.shape)
print("✅ news:", news.shape)
behaviors.head()
# Out:
# ✅ behaviors: (73152, 5)
# ✅ news: (42416, 8)
#    impression_id user_id                    time  \
# 0              1  U80234  11/15/2019 12:37:50 PM
# 1              2  U60458   11/15/2019 7:11:50 AM
# 2              3  U44190   11/15/2019 9:55:12 AM
# 3              4  U87380   11/15/2019 3:12:46 PM
# 4              5   U9444   11/15/2019 8:25:46 AM
#
#                                              history  \
# 0  N55189 N46039 N51741 N53234 N11276 N264 N40716...
# 1  N58715 N32109 N51180 N33438 N54827 N28488 N611...
# 2  N56253 N1150 N55189 N16233 N61704 N51706 N5303...
# 3  N63554 N49153 N28678 N23232 N43369 N58518 N444...
# 4                 N51692 N18285 N26015 N22679 N55556
#
#                                          impressions
# 0  N28682-0 N48740-0 N31958-1 N34130-0 N6916-0 N5...
# 1  N20036-0 N23513-1 N32536-0 N46976-0 N35216-0 N...
# 2  N36779-0 N62365-0 N58098-0 N5472-0 N13408-0 N5...
# 3  N6950-0 N60215-0 N6074-0 N11930-0 N6916-0 N248...
# 4  N5940-1 N23513-0 N49285-0 N23355-0 N19990-0 N3...

# %%
news.head()
# Out:
#   news_id   category      subcategory  \
# 0  N55528  lifestyle  lifestyleroyals
# 1  N18955     health          medical
# 2  N61837       news        newsworld
# 3  N53526     health           voices
# 4  N38324     health          medical
#
#                                                title  \
# 0  The Brands Queen Elizabeth, Prince Charles, an...
# 1  Dispose of unwanted prescription drugs during ...
# 2  The Cost of Trump's Aid Freeze in the Trenches...
# 3  I Was An NBA Wife. Here's How It Affected My M...
# 4  How to Get Rid of Skin Tags, According to a De...
#
#                                             abstract  \
# 0  Shop the notebooks, jackets, and more that the...
# 1                                                NaN
# 2  Lt. Ivan Molchanets peeked over a parapet of s...
# 3  I felt like I was a fraud, and being an NBA wi...
# 4  They seem harmless, but there's a very good re...
#
#                                              url  \
# 0  https://assets.msn.com/labs/mind/AAGH0ET.html
# 1  https://assets.msn.com/labs/mind/AAISxPN.html
# 2  https://assets.msn.com/labs/mind/AAJgNsz.html
# 3  https://assets.msn.com/labs/mind/AACk2N6.html
# 4  https://assets.msn.com/labs/mind/AAAKEkt.html
#
#                                             entities  \
# 0  [{"Label": "Prince Philip, Duke of Edinburgh",...
# 1  [{"Label": "Drug Enforcement Administration", ...
# 2                                                 []
# 3                                                 []
# 4  [{"Label": "Skin tag", "Type": "C", "WikidataI...
#
#                                    abstract_entities
# 0                                                 []
# 1                                                 []
# 2  [{"Label": "Ukraine", "Type": "G", "WikidataId...
# 3  [{"Label": "National Basketball Association", ...
# 4  [{"Label": "Skin tag", "Type": "C", "WikidataI...

# %% [markdown]
# Giữ lại các cột cần thiết

# %%
behaviors = behaviors[['user_id', 'history', 'impressions']]
news = news[['news_id', 'category', 'subcategory', 'title', 'entities']]

# %% [markdown]
# Chuẩn hóa cột entities trong news

# %%
def extract_wikidata_ids(entity_str):
    try:
        entities = ast.literal_eval(entity_str)
        return [e['WikidataId'] for e in entities if 'WikidataId' in e]
    except:
        return []

news['entity_ids'] = news['entities'].apply(extract_wikidata_ids)
news.drop(columns=['entities'], inplace=True)

news.head()
# Out:
#   news_id   category      subcategory  \
# 0  N55528  lifestyle  lifestyleroyals
# 1  N18955     health          medical
# 2  N61837       news        newsworld
# 3  N53526     health           voices
# 4  N38324     health          medical
#
#                                                title               entity_ids
# 0  The Brands Queen Elizabeth, Prince Charles, an...  [Q80976, Q43274, Q9682]
# 1  Dispose of unwanted prescription drugs during ...                [Q622899]
# 2  The Cost of Trump's Aid Freeze in the Trenches...                       []
# 3  I Was An NBA Wife. Here's How It Affected My M...                       []
# 4  How to Get Rid of Skin Tags, According to a De...               [Q3179593]

# %% [markdown]
# Làm sạch dữ liệu behaviors

# %%
# Xử lý lịch sử đọc
behaviors['history'] = behaviors['history'].fillna('').apply(lambda x: x.split(' ') if x != '' else [])

# Xử lý impressions: N12345-0 → chỉ giữ N12345
behaviors['impressions'] = behaviors['impressions'].apply(lambda x: [i.split('-')[0] for i in x.split(' ')])
behaviors.head()
# Out:
#   user_id                                            history  \
# 0  U80234  [N55189, N46039, N51741, N53234, N11276, N264,...
# 1  U60458  [N58715, N32109, N51180, N33438, N54827, N2848...
# 2  U44190  [N56253, N1150, N55189, N16233, N61704, N51706...
# 3  U87380  [N63554, N49153, N28678, N23232, N43369, N5851...
# 4   U9444           [N51692, N18285, N26015, N22679, N55556]
#
#                                          impressions
# 0  [N28682, N48740, N31958, N34130, N6916, N5472,...
# 1  [N20036, N23513, N32536, N46976, N35216, N3677...
# 2  [N36779, N62365, N58098, N5472, N13408, N55036...
# 3  [N6950, N60215, N6074, N11930, N6916, N24802, ...
# 4  [N5940, N23513, N49285, N23355, N19990, N31958...

# %% [markdown]
# Gộp dữ liệu behaviors và news
#
# Chuyển mỗi dòng của behaviors thành danh sách tin thực tế (news info) mà người dùng tương tác hoặc nhìn thấy

# %%
# Gộp behaviors với thông tin news theo mã tin
merged = behaviors.explode('impressions').merge(news, left_on='impressions', right_on='news_id', how='left')

# Giữ lại các cột chính
merged = merged[['user_id', 'impressions', 'category', 'subcategory', 'title', 'entity_ids']]

merged.head()
# Out:
#   user_id impressions       category   subcategory  \
# 0  U80234      N28682         sports  football_nfl
# 1  U80234      N48740      lifestyle        voices
# 2  U80234      N31958         sports  football_nfl
# 3  U80234      N34130             tv  tv-celebrity
# 4  U80234       N6916  entertainment     celebrity
#
#                                                title  \
# 0  Browns apologize to Mason Rudolph, call Myles ...
# 1  I've been writing about tiny homes for a year ...
# 2  Opinion: Colin Kaepernick is about to get what...
# 3  The Kardashians Face Backlash Over 'Insensitiv...
# 4  THEN AND NOW: What all your favorite '90s star...
#
#                         entity_ids
# 0  [Q18207047, Q223527, Q19666923]
# 1                               []
# 2                         [Q82496]
# 3                               []
# 4                               []

# %%
merged.to_csv('merged_clean.csv', index=False)
print("✅ Đã lưu file: merged_clean.csv")
# Out:
# ✅ Đã lưu file: merged_clean.csv
